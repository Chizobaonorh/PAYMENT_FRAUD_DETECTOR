# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("./dataset/credit_card.csv")

type = data["type"].value_counts()
transactions = type.index
quantity = type.values

figure = plt.pie(
                values=quantity,
                names=transactions,
                title="Distribution of Transaction Type"
                )

figure.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       8 transactions = type.index
#       9 quantity = type.values
# ---> 11 figure = plt.pie(
#      12                 values=quantity,
#      13                 names=transactions,
#      14                 title="Distribution of Transaction Type"
#      15                 )
#      17 figure.show()
#
# File ~/projects/PAYMENT_FRAUD_DETECTOR/venv/lib/python3.12/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# TypeError: pie() got an unexpected keyword argument 'values'
